# %%
# Dependencies and Setup
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Read CSV
got_data = pd.read_csv("merge_sample_after_filter.csv")
got_data
# Out:
#      Unnamed: 0  index  Year Team  GameNo D/N  Attendance API DATE Format  \
# 0             0     80  2009  BOS       1   D       37057      2009-04-07
# 1             1     82  2009  BOS       3   D       37784      2009-04-09
# 2             2     85  2009  BOS      12   D       37869      2009-04-19
# 3             3     86  2009  BOS      13   D       37865      2009-04-20
# 4            20    247  2010  BOS      12   D       37143      2010-04-18
# 5            21    248  2010  BOS      13   D       37609      2010-04-19
# 6            23    260  2010  BOS      31   D       37138      2010-05-08
# 7            24    264  2010  BOS      35   D       37198      2010-05-12
# 8            40    322  2010  BOS     162   D       37453      2010-10-03
# 9            41    404  2011  BOS       7   D       37178      2011-04-08
# 10           42    405  2011  BOS       8   D       37488      2011-04-09
# 11           43    410  2011  BOS      13   D       37310      2011-04-16
# ...

# %%
# Create a dataframe based on the values in the "attendance rate column
attendance_rate_df = pd.DataFrame(got_data, columns = ['Year', 'Team','Attendance Rate'])

# %%
# Print DataFrame
attendance_rate_df
# Out:
#      Year Team  Attendance Rate
# 0    2009  BOS       100.197383
# 1    2009  BOS       102.163098
# 2    2009  BOS       102.392927
# 3    2009  BOS       102.382111
# 4    2010  BOS       100.424485
# 5    2010  BOS       101.684421
# 6    2010  BOS       100.410966
# 7    2010  BOS       100.573190
# 8    2010  BOS       101.262640
# 9    2011  BOS       100.304870
# 10   2011  BOS       101.141238
# 11   2011  BOS       100.661001
# 12   2011  BOS       101.988399
# 13   2011  BOS       102.295967
# 14   2011  BOS       100.037771
# 15   2011  BOS        99.859706
# 16   2011  BOS       101.243761
# 17   2012  BOS        99.905576
# 18   2012  BOS       101.386678
# 19   2012  BOS       100.882186
# 20   2013  BOS        89.123574
# 21   2013  BOS        94.947533
# 22   2013  BOS       101.019665
# 23   2013  BOS        94.823447
# 24   2013  BOS        84.926223
# 25   2013  BOS        98.470503
# 26   2013  BOS        99.932562
# 27   2014  BOS        99.074748
# ...

# %%
# filter columns for year 2009
# does year equals to 2009?
# is_2009 is a boolean variable with True or False in it
is_2009 = attendance_rate_df ['Year']==2009
print(is_2009.head())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Year, dtype: bool

# %%
# Create a dataframe based on the values in the "temperature and precipitation" columns
temperature_df = pd.DataFrame(got_data, columns = ['Year', 'Team','D/N', 'Temperature', 'Precipitation'])

# %%
# Print DataFrame
df
# Out:
#      Year Team D/N  Temperature  Precipitation
# 0    2009  BOS   D        47.67         0.0000
# 1    2009  BOS   D        58.28         0.0000
# 2    2009  BOS   D        52.93         0.0000
# 3    2009  BOS   D        51.57         0.0000
# 4    2010  BOS   D        48.42         0.0011
# 5    2010  BOS   D        54.26         0.0000
# 6    2010  BOS   D        54.50         0.1115
# 7    2010  BOS   D        51.70         0.0000
# 8    2010  BOS   D        56.23         0.0000
# 9    2011  BOS   D        51.59         0.0000
# 10   2011  BOS   D        59.09         0.0000
# 11   2011  BOS   D        44.18         0.0000
# 12   2011  BOS   D        56.79         0.0033
# 13   2011  BOS   D        56.60         0.0000
# 14   2011  BOS   D        56.85         0.0000
# 15   2011  BOS   D        54.43         0.0000
# 16   2011  BOS   D        57.84         0.0000
# 17   2012  BOS   D        59.77         0.0000
# 18   2012  BOS   D        59.30         0.0000
# ...

# %%
# Scatter Plot for Inclimate Weather Games vs. Fan Attendance Cubs 2009 Season
plt.style.use('ggplot')
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
# Set Y limit for clarity
plt.ylim(0, 20)
# Out:
# <img src="data:image/png;base64,..." width="432">
# (0, 20)
# <img src="data:image/png;base64,..." width="432">

# %% [raw]
# # Create Scatterplot
# Temp_Lat_Scatter = ax.scatter(
# location_data["GameNo"],
# location_data["Attendance"],
# color="blue"
# )

# %%
# Add Labels and Title
ax.set_xlabel("Inclimate Weather Games")
ax.set_ylabel("Fan Attendance")
ax.set_title(f"Obsessive Fans {2009 Season}")
# Out:
#   File "<fstring>", line 1
#     (2009 Season)
#                ^
# SyntaxError: invalid syntax

# %%
# Save fig to file
plt.savefig('2009 Cub Season.png')

# %%
# Show
plt.show()
